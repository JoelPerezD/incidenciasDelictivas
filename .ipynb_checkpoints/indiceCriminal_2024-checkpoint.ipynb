# %% [markdown]
# # Delitos en mexico hasta abril del 2024

# %% [markdown]
# En el siguiente proyecto se realiza la conexion a una base de datos con los datos de https://www.gob.mx/sesnsp/acciones-y-programas/datos-abiertos-de-incidencia-delictiva de la seccion Reportes de incidencia delictiva al mes de abril 2024 (Nueva metodología).

# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate

# %% [markdown]
# Se realiza la conexion a la base de datos local

# %%
def connect_to_db():
    return mysql.connector.connect(
        host="localhost",
        user="root",
        password="Steven77*",
        database="crimenes"
    )

# %% [markdown]
# Metodo para ejecutar querys, consultas a la base de datos

# %%
def fetch_data(query):
    connection = connect_to_db()
    cursor = connection.cursor()
    cursor.execute(query)
    data = cursor.fetchall()
    columns = [col[0] for col in cursor.description]
    df = pd.DataFrame(data, columns=columns)
    cursor.close()
    connection.close()
    return df

# %%
query = "SELECT * FROM crimenes.indicecriminal where Entidad='sonora'"
data_df = fetch_data(query)
data_df
# comprobamos que se realize correctamente la consulta, en donde podemos revisar los delitos rgistrados en sonora del año 2015 hasta el 2023
# Out:
#       Año  Clave_Ent Entidad  \
# 0    2015         26  Sonora
# 1    2015         26  Sonora
# 2    2015         26  Sonora
# 3    2015         26  Sonora
# 4    2015         26  Sonora
# ..    ...        ...     ...
# 877  2023         26  Sonora
# 878  2023         26  Sonora
# 879  2023         26  Sonora
# 880  2023         26  Sonora
# 881  2023         26  Sonora
#
#                                 Bien jurídico afectado  \
# 0                     La vida y la Integridad corporal
# 1                     La vida y la Integridad corporal
# 2                     La vida y la Integridad corporal
# 3                     La vida y la Integridad corporal
# 4                     La vida y la Integridad corporal
# ..                                                 ...
# 877  Otros bienes jurídicos afectados (del fuero co...
# 878  Otros bienes jurídicos afectados (del fuero co...
# 879  Otros bienes jurídicos afectados (del fuero co...
# 880  Otros bienes jurídicos afectados (del fuero co...
# 881  Otros bienes jurídicos afectados (del fuero co...
#
#                                 Tipo de delito  \
# 0                                    Homicidio
# 1                                    Homicidio
# 2                                    Homicidio
# 3                                    Homicidio
# 4                                    Homicidio
# ..                                         ...
# 877                              Falsificación
# 878                   Contra el medio ambiente
# 879  Delitos cometidos por servidores públicos
# 880                                Electorales
# 881              Otros delitos del Fuero Común
#
#                              Subtipo de delito  \
# 0                             Homicidio doloso
# 1                             Homicidio doloso
# 2                             Homicidio doloso
# 3                             Homicidio doloso
# 4                            Homicidio culposo
# ..                                         ...
# 877                              Falsificación
# 878                   Contra el medio ambiente
# 879  Delitos cometidos por servidores públicos
# 880                                Electorales
# 881              Otros delitos del Fuero Común
#
#                                      Modalidad  Enero  Febrero  Marzo  Abril  \
# 0                            Con arma de fuego     23       19     34     16
# 1                              Con arma blanca      4        7      3     10
# 2                            Con otro elemento      9       17     15      6
# 3                              No especificado      0        0      0      0
# 4                            Con arma de fuego      0        0      0      0
# ..                                         ...    ...      ...    ...    ...
# 877                              Falsificación      3        1      2      4
# 878                   Contra el medio ambiente      0        0      0      0
# 879  Delitos cometidos por servidores públicos      8       10     16      6
# 880                                Electorales      0        0      0      0
# 881              Otros delitos del Fuero Común    163      221    211    185
#
#      Mayo  Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre
# 0      30     38     34      50          22       36         20         19
# 1       3      6     13       9          15       12         11          1
# 2      24     18     20      10          11        8         10          6
# 3       0      0      0       0           0        0          0          0
# 4       0      0      0       0           0        0          0          0
# ..    ...    ...    ...     ...         ...      ...        ...        ...
# 877     3      5      6       9           6        2          5          4
# 878     0      0      0       1           1        0          0          0
# 879     7     12      6       2           5        6          3          2
# 880     0      0      0       0           0        0          0          0
# 881   178    217    197     256         206      199        182        144
#
# [882 rows x 19 columns]
